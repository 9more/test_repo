# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
model =[LinearRegression(),Ridge(),
        Lasso(),ElasticNet()]
def data_processing(df,target):
  poly, penal= np.arange(1,101), np.linspace(1,100,100)
  df= pd.read_csv(df)
  df=df.select_dtypes(incliude='numeric')
  df.apply(lambda x: x.fillna(x.mean()),axis=0)
  y,X= df('target'), df.drop('target')

  return df

  def model_train(df, target):
    j=data_processing(df,target)
    for i in model:
      if i == model[0]:
        u=i.fit(df[0],df[1])
        u.score(df[0],df[1])
      elif i == model[1]:
        u=i.fit(df[0],df[1])
        u.score(df[0],df[1])
      else:pass
      for j in poly:
        u=i.fit(df[0],df[1])


  def best_model(df,target):
    df=data_processing(df,target)
    j=model_train(df,target)
    u=i.fit(df[0],df[1])
    u=i.fit(df[0],df[1])
    u=j.fit(df[0])
    return u.coef_

  def model_pred(df,target):
    df=data_processing(df,target)
    pass
