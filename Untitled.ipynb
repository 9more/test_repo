# %%
import csv
import kagglehub

# Download latest version
#path = kagglehub.dataset_download("dongrelaxman/amazon-reviews-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/imohekpenyong/.cache/kagglehub/datasets/dongrelaxman/amazon-reviews-dataset/versions/1

# %%
with open('Amazon_Reviews.csv', 'r', newline='') as f:
    reader = csv.DictReader(f)
    with open('data.csv', 'w', newline='') as out_f:
        fieldnames = ['Country', 'Review Date', 'Review Title', 'Review Text', 'Rating']  
        writer = csv.DictWriter(out_f, fieldnames=fieldnames)
        writer.writeheader()
        for row in reader:
            writer.writerow({
                'Country': row['Country'],
                'Review Date': row['Review Date'],
                'Review Title': row['Review Title'],
                'Review Text' : row['Review Text'],
                'Rating': row['Rating']
            })

# %%
import pandas as pd
import json
#a=json.dumps('Amazon_Reviews.csv', )
df = pd.read_csv('data.csv', on_bad_lines='skip')
df.head(10)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21214 entries, 0 to 21213
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       21054 non-null  str
#  1   Review Date   21055 non-null  str
#  2   Review Title  21055 non-null  str
#  3   Review Text   21055 non-null  str
#  4   Rating        21055 non-null  str
# dtypes: str(5)
# memory usage: 828.8 KB

# %%
with open('Amazon_Reviews.csv', 'r', newline='') as f:
    reader = csv.reader(f)
    with open('filtered3.csv', 'w', newline='') as out_f:
        writer = csv.writer(out_f)
        for row in reader:
            selected = [row[2].strip(), row[4]
            writer.writerow(selected)
# Out:
# ['Country', 'Review Count', 'Review Date']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 9
#       6 writer = csv.writer(out_f)
#       8 for row in reader:
# ----> 9     selected = [row[2].strip(), row[4], row[6]]
#      10     writer.writerow(selected)
#
# IndexError: list index out of range

# %%
# Out:
# "Amazon_Reviews.csv"
